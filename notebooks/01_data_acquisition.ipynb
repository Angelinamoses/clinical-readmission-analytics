# %% [markdown]
# # Clinical Readmission Analytics
#
# ## Data Acquisition and Initial Exploration
#
# This notebook retrieves the dataset from the UCI Machine Learning Repository and performs an initial inspection of its structure, metadata, dimensions, and data quality.
#
# ---

# %%
from ucimlrepo import fetch_ucirepo

import pandas as pd
import numpy as np

pd.set_option("display.max_columns",None)

# %%
# fetch dataset

diabetes_readmission = fetch_ucirepo(id=296)
# Out:
# c:\Users\johnm\clinical-readmission-analytics\venv\Lib\site-packages\ucimlrepo\fetch.py:97: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data_url)

# %%
# dataset metadata

diabetes_readmission.metadata
# Out:
# {'uci_id': 296,
#  'name': 'Diabetes 130-US Hospitals for Years 1999-2008',
#  'repository_url': 'https://archive.ics.uci.edu/dataset/296/diabetes+130-us+hospitals+for+years+1999-2008',
#  'data_url': 'https://archive.ics.uci.edu/static/public/296/data.csv',
# ...

# %%
diabetes_readmission.variables
# Out:
#                         name     role         type demographic  \
# 0               encounter_id       ID                     None
# 1                patient_nbr       ID                     None
# 2                       race  Feature  Categorical        Race
# 3                     gender  Feature  Categorical      Gender
# 4                        age  Feature  Categorical         Age
# 5                     weight  Feature  Categorical        None
# 6          admission_type_id  Feature  Categorical        None
# 7   discharge_disposition_id  Feature  Categorical        None
# 8        admission_source_id  Feature  Categorical        None
# 9           time_in_hospital  Feature      Integer        None
# 10                payer_code  Feature  Categorical        None
# 11         medical_specialty  Feature  Categorical        None
# 12        num_lab_procedures  Feature      Integer        None
# 13            num_procedures  Feature      Integer        None
# ...

# %%
# Create a dataframe

X = diabetes_readmission.data.features
y = diabetes_readmission.data.targets

# %%
X.head()
# Out:
#               race  gender      age weight  admission_type_id  \
# 0        Caucasian  Female   [0-10)    NaN                  6
# 1        Caucasian  Female  [10-20)    NaN                  1
# 2  AfricanAmerican  Female  [20-30)    NaN                  1
# 3        Caucasian    Male  [30-40)    NaN                  1
# 4        Caucasian    Male  [40-50)    NaN                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital payer_code  \
# 0                        25                    1                 1        NaN
# 1                         1                    7                 3        NaN
# 2                         1                    7                 2        NaN
# 3                         1                    7                 2        NaN
# 4                         1                    7                 1        NaN
#
#           medical_specialty  num_lab_procedures  num_procedures  \
# ...

# %%
y.head()
# Out:
#   readmitted
# 0         NO
# 1        >30
# 2         NO
# 3         NO
# 4         NO

# %%
df = pd.concat([X,y], axis=1)

# %%
df.shape
# Out:
# (101766, 48)

# %%
df.head()
# Out:
#               race  gender      age weight  admission_type_id  \
# 0        Caucasian  Female   [0-10)    NaN                  6
# 1        Caucasian  Female  [10-20)    NaN                  1
# 2  AfricanAmerican  Female  [20-30)    NaN                  1
# 3        Caucasian    Male  [30-40)    NaN                  1
# 4        Caucasian    Male  [40-50)    NaN                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital payer_code  \
# 0                        25                    1                 1        NaN
# 1                         1                    7                 3        NaN
# 2                         1                    7                 2        NaN
# 3                         1                    7                 2        NaN
# 4                         1                    7                 1        NaN
#
#           medical_specialty  num_lab_procedures  num_procedures  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   race                      99493 non-null   object
#  1   gender                    101766 non-null  object
#  2   age                       101766 non-null  object
#  3   weight                    3197 non-null    object
#  4   admission_type_id         101766 non-null  int64
#  5   discharge_disposition_id  101766 non-null  int64
#  6   admission_source_id       101766 non-null  int64
#  7   time_in_hospital          101766 non-null  int64
#  8   payer_code                61510 non-null   object
#  9   medical_specialty         51817 non-null   object
#  10  num_lab_procedures        101766 non-null  int64
#  11  num_procedures            101766 non-null  int64
#  12  num_medications           101766 non-null  int64
# ...

# %%
# missing value Assessment
missing = (
    df.isnull()
      .sum()
      .sort_values(ascending=False)
)

missing.head(20)
# Out:
# weight                      98569
# max_glu_serum               96420
# A1Cresult                   84748
# medical_specialty           49949
# payer_code                  40256
# race                         2273
# diag_3                       1423
# diag_2                        358
# diag_1                         21
# time_in_hospital                0
# num_lab_procedures              0
# admission_source_id             0
# admission_type_id               0
# discharge_disposition_id        0
# gender                          0
# age                             0
# number_inpatient                0
# number_emergency                0
# number_outpatient               0
# num_medications                 0
# dtype: int64

# %%
# calculating percentages

missing_percent = (
    df.isnull()
    .mean()
    .mul(100)
    .round(2)
    .sort_values(ascending=False)
)

missing_percent.head(20)
# Out:
# weight                      96.86
# max_glu_serum               94.75
# A1Cresult                   83.28
# medical_specialty           49.08
# payer_code                  39.56
# race                         2.23
# diag_3                       1.40
# diag_2                       0.35
# diag_1                       0.02
# time_in_hospital             0.00
# num_lab_procedures           0.00
# admission_source_id          0.00
# admission_type_id            0.00
# discharge_disposition_id     0.00
# gender                       0.00
# age                          0.00
# number_inpatient             0.00
# number_emergency             0.00
# number_outpatient            0.00
# num_medications              0.00
# dtype: float64

# %%
missing_summary = pd.DataFrame({
    "Missing Count": df.isnull().sum(),
    "Missing Percent": (
        df.isnull().mean() * 100
    ).round(2)
})

missing_summary.sort_values(
    by="Missing Percent",
    ascending=False
).head(20)
# Out:
#                           Missing Count  Missing Percent
# weight                            98569            96.86
# max_glu_serum                     96420            94.75
# A1Cresult                         84748            83.28
# medical_specialty                 49949            49.08
# payer_code                        40256            39.56
# race                               2273             2.23
# diag_3                             1423             1.40
# diag_2                              358             0.35
# diag_1                               21             0.02
# time_in_hospital                      0             0.00
# num_lab_procedures                    0             0.00
# admission_source_id                   0             0.00
# admission_type_id                     0             0.00
# discharge_disposition_id              0             0.00
# gender                                0             0.00
# ...

# %%
import missingno as msno

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %%
missing_summary.sort_values(
    by="Missing Percent",
    ascending=False
).head(10)
# Out:
#                    Missing Count  Missing Percent
# weight                     98569            96.86
# max_glu_serum              96420            94.75
# A1Cresult                  84748            83.28
# medical_specialty          49949            49.08
# payer_code                 40256            39.56
# race                        2273             2.23
# diag_3                      1423             1.40
# diag_2                       358             0.35
# diag_1                        21             0.02
# time_in_hospital               0             0.00

# %% [markdown]
# ## Initial Data Quality Findings
#
# ### Major Missingness
#
# - weight contains 96.86% missing values
# - max_glu_serum contains 94.75% missing values
# - A1Cresult contains 83.28% missing values
# - medical_specialty contains 49.08% missing values
# - payer_code contains 39.56% missing values
#
# ### Potential Actions
#
# - Investigate whether missing values represent unrecorded information or clinically meaningful categories.
# - Evaluate columns with >90% missingness for removal.
# - Retain diagnosis columns due to low missingness.

# %%
df["readmitted"].value_counts()
# Out:
# readmitted
# NO     54864
# >30    35545
# <30    11357
# Name: count, dtype: int64

# %%
df["race"].value_counts(dropna=False)
# Out:
# race
# Caucasian          76099
# AfricanAmerican    19210
# NaN                 2273
# Hispanic            2037
# Other               1506
# Asian                641
# Name: count, dtype: int64

# %%
df["max_glu_serum"].value_counts(dropna=False)
# Out:
# max_glu_serum
# NaN     96420
# Norm     2597
# >200     1485
# >300     1264
# Name: count, dtype: int64

# %%
df["A1Cresult"].value_counts(dropna=False)
# Out:
# A1Cresult
# NaN     84748
# >8       8216
# Norm     4990
# >7       3812
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        admission_type_id  discharge_disposition_id  admission_source_id  \
# count      101766.000000             101766.000000        101766.000000
# mean            2.024006                  3.715642             5.754437
# std             1.445403                  5.280166             4.064081
# min             1.000000                  1.000000             1.000000
# 25%             1.000000                  1.000000             1.000000
# 50%             1.000000                  1.000000             7.000000
# 75%             3.000000                  4.000000             7.000000
# max             8.000000                 28.000000            25.000000
#
#        time_in_hospital  num_lab_procedures  num_procedures  num_medications  \
# count     101766.000000       101766.000000   101766.000000    101766.000000
# mean           4.395987           43.095641        1.339730        16.021844
# std            2.985108           19.674362        1.705807         8.127566
# ...

# %%
df.describe(include="object")
# Out:
#              race  gender      age    weight payer_code medical_specialty  \
# count       99493  101766   101766      3197      61510             51817
# unique          5       3       10         9         17                72
# top     Caucasian  Female  [70-80)  [75-100)         MC  InternalMedicine
# freq        76099   54708    26068      1336      32439             14635
#
#         diag_1  diag_2  diag_3 max_glu_serum A1Cresult metformin repaglinide  \
# count   101745  101408  100343          5346     17018    101766      101766
# unique     716     748     789             3         3         4           4
# top        428     276     250          Norm        >8        No          No
# freq      6862    6752   11555          2597      8216     81778      100227
#
#        nateglinide chlorpropamide glimepiride acetohexamide glipizide  \
# count       101766         101766      101766        101766    101766
# ...

# %% [markdown]
# ## Initial Dataset Observations
#
# ### Dataset Characteristics
#
# - 101,766 patient encounters
# - 48 variables
# - Mix of demographic, diagnostic, medication, and utilization features
#
# ### Missing Data Findings
#
# - Weight is missing in 96.86% of records.
# - A1Cresult is missing in 83.28% of records.
# - max_glu_serum is missing in 94.75% of records.
# - Medical specialty is missing in 49.08% of records.
#
# ### Target Variable
#
# The readmitted variable contains three categories:
#
# - NO
# - '>30'
# - '<30'
#
# representing different readmission outcomes.
